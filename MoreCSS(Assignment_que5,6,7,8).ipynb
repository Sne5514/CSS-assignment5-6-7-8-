# %% [markdown]
# 5. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font align center to the page, below the heading have an image of Google fonts and a paragraph about Google fonts in font “Montserrat” paragraph font style should be“montserrat” font.
#
#  -
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Google Fonts Blog</title>
#
#   <!-- Google Fonts -->
#   <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400&family=Oswald:wght@500&display=swap" rel="stylesheet">
#
#   <style>
#         body {
#             font-family: 'Montserrat', sans-serif;
#             margin: 0;
#             padding: 20px;
#             text-align: center;
#             background-color: #f9f9f9;
#         }
#
#         h1 {
#             font-family: 'Oswald', sans-serif;
#             text-align: center;
#             font-size: 3em;
#             color: #333;
#         }
#
#         img {
#             max-width: 100%;
#             height: auto;
#             margin: 20px 0;
#         }
#
#         p {
#             font-family: 'Montserrat', sans-serif;
#             font-size: 1.2em;
#             max-width: 800px;
#             margin: 0 auto;
#             color: #555;
#             line-height: 1.6;
#         }
#     </style>
# </head>
# <body>
#
#   <h1>Google Fonts</h1>
#
#   <img src="data:image/png;base64,..." alt="Google Fonts Logo">
#
#   <p>
#      Google Fonts is a free and open-source library of web fonts provided by Google. It offers a wide range of typefaces that can be easily integrated into websites using simple CSS links. Google Fonts enhances web typography by offering high-quality fonts that are optimized for readability and performance across different devices and screen sizes.
#   </p>
#
# </body>
# </html>
#
# ```
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Google Fonts Blog</title>
#
#   <!-- Google Fonts -->
#   <link href="https://fonts.googleapis.com/css2?family=Montserrat:wght@400&family=Oswald:wght@500&display=swap" rel="stylesheet">
#
#   <style>
#         body {
#             font-family: 'Montserrat', sans-serif;
#             margin: 0;
#             padding: 20px;
#             text-align: center;
#             background-color: #f9f9f9;
#         }
#
#         h1 {
#             font-family: 'Oswald', sans-serif;
#             text-align: center;
#             font-size: 3em;
#             color: #333;
#         }
#
#         img {
#             max-width: 100%;
#             height: auto;
#             margin: 20px 0;
#         }
#
#         p {
#             font-family: 'Montserrat', sans-serif;
#             font-size: 1.2em;
#             max-width: 800px;
#             margin: 0 auto;
#             color: #555;
#             line-height: 1.6;
#         }
#     </style>
# </head>
# <body>
#
#   <h1>Google Fonts</h1>
#
#   <img src="data:image/png;base64,..." alt="Google Fonts Logo">
#
#   <p>
#      Google Fonts is a free and open-source library of web fonts provided by Google. It offers a wide range of typefaces that can be easily integrated into websites using simple CSS links. Google Fonts enhances web typography by offering high-quality fonts that are optimized for readability and performance across different devices and screen sizes.
#   </p>
#
# </body>
# </html>

# %% [markdown]
# 6. Create a simple website as mentioned in the below image. You can get the assets by visiting https://pwskills.com/about-us.
#
#  -
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>About Us - PW Skills</title>
#   <style>
# body {
#     font-family: Arial, sans-serif;
#     margin: 0;
#     padding: 0;
#     line-height: 1.6;
# }
#
# header {
#     background: #333;
#     color: #fff;
#     padding: 1rem 0;
#     text-align: center;
# }
#
# .logo {
#     width: 150px;
# }
#
# nav ul {
#     list-style: none;
#     padding: 0;
# }
#
# nav ul li {
#     display: inline;
#     margin: 0 10px;
# }
#
# nav ul li a {
#     color: #fff;
#     text-decoration: none;
# }
#
# main {
#     padding: 2rem;
# }
#
# section {
#     margin-bottom: 2rem;
# }
#
# footer {
#     background: #333;
#     color: #fff;
#     text-align: center;
#     padding: 1rem 0;
#     position: fixed;
#     width: 100%;
#     bottom: 0;
# }
# </style>
# </head>
# <body>
#     <header>
#         <img src="data:image/png;base64,..." alt="PW Skills Logo" class="logo">
#         <nav>
#           <ul>
#                 <li><a href="index.html">Home</a></li>
#                 <li><a href="courses.html">Courses</a></li>
#                 <li><a href="about.html">About Us</a></li>
#                 <li><a href="contact.html">Contact</a></li>
#             </ul>
#         </nav>
#     </header>
#     <main>
#         <section class="mission">
#             <h1>Our Mission</h1>
#             <p>PW Skills aims to empower every individual by providing exceptional upskilling courses at affordable rates, ensuring accessibility for all.</p>
#         </section>
#         <section class="achievements">
#             <h2>Our Achievements</h2>
#             <ul>
#                 <li>600+ Different Courses</li>
#                 <li>7000+ Students Enrolled</li>
#                 <li>1000+ Successful Transitions</li>
#             </ul>
#         </section>
#         <section class="contact">
#             <h2>Contact Us</h2>
#             <p>Email: support@pwskills.com</p>
#             <p>Phone: +918448982581</p>
#         </section>
#     </main>
#     <footer>
#         <p>&copy; 2025 PW Skills. All rights reserved.</p>
#     </footer>
# </body>
# </html>
#
#
# ```
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>About Us - PW Skills</title>
#   <style>
# body {
#     font-family: Arial, sans-serif;
#     margin: 0;
#     padding: 0;
#     line-height: 1.6;
# }
#
# header {
#     background: #333;
#     color: #fff;
#     padding: 1rem 0;
#     text-align: center;
# }
#
# .logo {
#     width: 150px;
# }
#
# nav ul {
#     list-style: none;
#     padding: 0;
# }
#
# nav ul li {
#     display: inline;
#     margin: 0 10px;
# }
#
# nav ul li a {
#     color: #fff;
#     text-decoration: none;
# }
#
# main {
#     padding: 2rem;
# }
#
# section {
#     margin-bottom: 2rem;
# }
#
# footer {
#     background: #333;
#     color: #fff;
#     text-align: center;
#     padding: 1rem 0;
#     position: fixed;
#     width: 100%;
#     bottom: 0;
# }
# </style>
# </head>
# <body>
#     <header>
#         <img src="data:image/png;base64,..." alt="PW Skills Logo" class="logo">
#         <nav>
#           <ul>
#                 <li><a href="index.html">Home</a></li>
#                 <li><a href="courses.html">Courses</a></li>
#                 <li><a href="about.html">About Us</a></li>
#                 <li><a href="contact.html">Contact</a></li>
#             </ul>
#         </nav>
#     </header>
#     <main>
#         <section class="mission">
#             <h1>Our Mission</h1>
#             <p>PW Skills aims to empower every individual by providing exceptional upskilling courses at affordable rates, ensuring accessibility for all.</p>
#         </section>
#         <section class="achievements">
#             <h2>Our Achievements</h2>
#             <ul>
#                 <li>600+ Different Courses</li>
#                 <li>7000+ Students Enrolled</li>
#                 <li>1000+ Successful Transitions</li>
#             </ul>
#         </section>
#         <section class="contact">
#             <h2>Contact Us</h2>
#             <p>Email: support@pwskills.com</p>
#             <p>Phone: +918448982581</p>
#         </section>
#     </main>
#     <footer>
#         <p>&copy; 2025 PW Skills. All rights reserved.</p>
#     </footer>
# </body>
# </html>

# %% [markdown]
# 7.  Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as default and on hovering the card must be displayed clearly.Use CSS opacity to achieve this output.
#
#  -
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Centered Card</title>
#   <style>
#     body {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     height: 100vh;
#     background-color: #f0f0f0;
#     margin: 0;
# }
#     .card {
#     width: 300px;
#     padding: 20px;
#     background: rgba(255, 255, 255, 0.5); /* Semi-transparent */
#     border-radius: 10px;
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     transition: opacity 0.3s ease-in-out;
#     opacity: 0.5; /* Default opacity */
# }
#     .card:hover {
#     opacity: 1; /* Fully visible on hover */
# }
#     h2 {
#     margin: 0;
# }
#     .card p {
#     font-size: 16px;
#     font-weight: bold;
#     margin-top: 10px;
# }
#     </style>
# </head>
# <body>
#   <div class="card">
#   <img src="data:image/jpeg;base64,..." alt="Course Image">
#   <p>Course Name: PW Skills full stack web development</p>
#     </div>
# </body>
# ```
#
#
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Centered Card</title>
#   <style>
#     body {
#     display: flex;
#     justify-content: center;
#     align-items: center;
#     height: 100vh;
#     background-color: #f0f0f0;
#     margin: 0;
# }
#     .card {
#     width: 300px;
#     padding: 20px;
#     background: rgba(255, 255, 255, 0.5); /* Semi-transparent */
#     border-radius: 10px;
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
#     text-align: center;
#     transition: opacity 0.3s ease-in-out;
#     opacity: 0.5; /* Default opacity */
# }
#     .card:hover {
#     opacity: 1; /* Fully visible on hover */
# }
#     h2 {
#     margin: 0;
# }
#     .card p {
#     font-size: 16px;
#     font-weight: bold;
#     margin-top: 10px;
# }
#     </style>
# </head>
# <body>
#   <div class="card">
#   <img src="data:image/jpeg;base64,..." alt="Course Image">
#   <p>Course Name: PW Skills full stack web development</p>
#     </div>
# </body>

# %% [markdown]
# 8. Create a simple list of items as mentioned in the below image.
#
#  -
#
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Requirements List</title>
#   <style>
#         /* General styling */
# body {
#     font-family: Arial, sans-serif;
#     background-color: #f8f8f8;
#     padding: 20px;
# }
# /* Box container */
# .requirements-box {
#     background-color: white;
#     padding: 15px;
#     border: 2px solid #000;
#     width: 50%;
#     margin: auto;
#     box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.2);
# }
# /* Title styling */
# .requirements-box h2 {
#     font-size: 24px;
#     font-weight: bold;
# }
# /* List styling */
# .requirements-box ul {
#     list-style-type: lower-roman;
#     padding-left: 20px;
# }
# .requirements-box ul li {
#     font-size: 18px;
#     margin-bottom: 5px;
# }
#     </style>
# </head>
# <body>
#   <div class="requirements-box">
#     <h2>Requirements</h2>
#       <ul>
#           <li>System with a minimum i3 processor or better.</li>
#           <li>At least 4 GB of RAM.</li>
#           <li>Working internet connection.</li>
#           <li>Dedication to learn.</li>
#         </ul>
#     </div>
# </body>
# </html>
# ```
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Requirements List</title>
#   <style>
#         /* General styling */
# body {
#     font-family: Arial, sans-serif;
#     background-color: #f8f8f8;
#     padding: 20px;
# }
# /* Box container */
# .requirements-box {
#     padding: 15px;
#     border: 2px solid #000;
#     width: 50%;
#     margin: auto;
#     box-shadow: 2px 2px 5px rgba(0, 0, 0, 0.2);
# }
# /* Title styling */
# .requirements-box h2 {
#     font-size: 24px;
#     font-weight: bold;
# }
# /* List styling */
# .requirements-box ul {
#     list-style-type: lower-roman;
#     padding-left: 20px;
# }
# .requirements-box ul li {
#     font-size: 18px;
#     margin-bottom: 5px;
# }
#     </style>
# </head>
# <body>
#   <div class="requirements-box">
#     <h2>Requirements</h2>
#       <ul>
#           <li>System with a minimum i3 processor or better.</li>
#           <li>At least 4 GB of RAM.</li>
#           <li>Working internet connection.</li>
#           <li>Dedication to learn.</li>
#         </ul>
#     </div>
# </body>
# </html>
